# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}
</style>
""")
# Out:
# <style>.container { width:80% !important; }</style>
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>

# %%
Y_M_PL = np.genfromtxt('Y_PL.txt',delimiter=',')
Y_M_HB = np.genfromtxt('Y_HB.txt',delimiter=',')

# %%
Y_A = np.genfromtxt('Y_A.txt')
Y_M_PL = np.genfromtxt('Y_PL.txt',delimiter=',')
Y_M_HB = np.genfromtxt('Y_HB.txt',delimiter=',')
#Y_M_CA = np.genfromtxt('Y_M_CA.txt')
#Y_M_HBC = np.genfromtxt('Y_M_HBC.txt')
#Y_D = np.genfromtxt('Y_D.txt')
ShR = np.genfromtxt('ShR.txt')

Y_A = Y_A.reshape((-1,1))
Y_PL = np.log10(Y_M_PL[0:401].reshape((-1,1))[6::7])
Y_HB = np.log10(Y_M_HB[0:401].reshape((-1,1))[6::7])
#Y_M_CA = Y_M_CA.reshape((-1,1))
#Y_M_HBC = Y_M_HBC.reshape((-1,1))
#Y_D = Y_D.reshape((-1,1))
ShR = ShR.reshape((-1,1))
Shear = np.log10(Y_M_PL[0:401].reshape((-1,1))[4::7])

# %% [markdown]
# # Flow Curves

# %%
Batch = 5
a=0
b=2
import matplotlib.font_manager
from matplotlib import rc
rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
rc('text', usetex=True)

plt.figure(figsize=(10,10),dpi=300)

plt.rc('font', size=20)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=22)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=22)    # legend fontsize
plt.rc('figure', titlesize=22)  # fontsize of the figure title

plt.plot(np.power(10,ShR[1::2]),np.power(10,Y_A[1::2]) , 'bP-', markerfacecolor='none', linewidth=1.5, markersize = 11.0)
#plt.plot(np.power(10,ShR[a::b]),np.power(10,Y_D[a::b]) , 'yd-', markerfacecolor='none', linewidth=1.5, markersize = 11.0)
plt.plot(np.power(10,Shear[::20]),np.power(10,Y_PL[::20]) , 'r<-' , markerfacecolor='none', linewidth=1.5, markersize = 11.0)
plt.plot(np.power(10,Shear[::20]),np.power(10,Y_HB[::20]) , 'gs-', markerfacecolor='none', linewidth=1.5, markersize = 11.0)
#plt.plot(np.power(10,ShR[a:b]),np.power(10,Y_M_CA[a:b]) , 'c<-' , markerfacecolor='none', linewidth=1.5, markersize = 11.0)
#plt.plot(np.power(10,ShR[2::3]),np.power(10,Y_M_HBC[2::3]) , 'go-', markerfacecolor='none', linewidth=1.5, markersize = 11.0)

#plt.plot(np.power(10,X_L[(Batch-1)*401:Batch*401]),np.power(10,Y_L[(Batch-1)*401:Batch*401]) , 'yd-', markerfacecolor='none', linewidth=3.0, markersize = 11.0)

plt.xlabel('Shear Rate [1/s]', fontname = 'Times New Roman', fontsize=40)
plt.ylabel('Viscosity [Pa.s]', fontname = 'Times New Roman', fontsize=40)
plt.legend(['Experiment','Power Law','Herschel–Bulkley'],loc='upper right')
#plt.title('Actual and Predicted Flow Curve for a Random Batch')

plt.xticks(np.arange(0,10, 1.0),fontname = "Times New Roman", fontsize=30)
plt.yticks(fontname = "Times New Roman", fontsize=30)
#plt.ylim(0.6,13)
plt.xscale("log")
plt.yscale("log")

plt.savefig('LF_Fitting_Models_Batch13.png',bbox_inches = 'tight')

plt.show()

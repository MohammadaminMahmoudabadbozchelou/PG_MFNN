# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}
</style>
""")
# Out:
# <style>.container { width:80% !important; }</style>
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>

# %%
Y_A = np.genfromtxt('UpTp02Batch13Y_A.txt')
Y_M02 = np.genfromtxt('UpTp02Batch13Y_M.txt')
Y_M03 = np.genfromtxt('UpTp03Batch13Y_M.txt')
Y_M04 = np.genfromtxt('UpTp04Batch13Y_M.txt')
Y_M05 = np.genfromtxt('UpTp05Batch13Y_M.txt')
Y_M06 = np.genfromtxt('UpTp06Batch13Y_M.txt')
Y_M07 = np.genfromtxt('UpTp07Batch13Y_M.txt')
Y_M08 = np.genfromtxt('UpTp08Batch13Y_M.txt')
Y_M09 = np.genfromtxt('UpTp09Batch13Y_M.txt')
Y_M10 = np.genfromtxt('UpTp10Batch13Y_M.txt')
Y_M11 = np.genfromtxt('UpTp11Batch13Y_M.txt')
Y_D02 = np.genfromtxt('UpTp02Batch13Y_D.txt')
Y_D03 = np.genfromtxt('UpTp03Batch13Y_D.txt')
Y_D04 = np.genfromtxt('UpTp04Batch13Y_D.txt')
Y_D05 = np.genfromtxt('UpTp05Batch13Y_D.txt')
Y_D06 = np.genfromtxt('UpTp06Batch13Y_D.txt')
Y_D07 = np.genfromtxt('UpTp07Batch13Y_D.txt')
Y_D08 = np.genfromtxt('UpTp08Batch13Y_D.txt')
Y_D09 = np.genfromtxt('UpTp09Batch13Y_D.txt')
Y_D10 = np.genfromtxt('UpTp10Batch13Y_D.txt')
Y_D11 = np.genfromtxt('UpTp11Batch13Y_D.txt')
ShR = np.genfromtxt('UpTp02Batch13ShR.txt')

Y_A = Y_A.reshape((-1,1))
Y_M02 = Y_M02.reshape((-1,1))
Y_D02 = Y_D02.reshape((-1,1))
Y_M03 = Y_M03.reshape((-1,1))
Y_D03 = Y_D03.reshape((-1,1))
Y_M04 = Y_M04.reshape((-1,1))
Y_D04 = Y_D04.reshape((-1,1))
Y_M05 = Y_M05.reshape((-1,1))
Y_D05 = Y_D05.reshape((-1,1))
Y_M06 = Y_M06.reshape((-1,1))
Y_D06 = Y_D06.reshape((-1,1))
Y_M07 = Y_M07.reshape((-1,1))
Y_D07 = Y_D07.reshape((-1,1))
Y_M08 = Y_M08.reshape((-1,1))
Y_D08 = Y_D08.reshape((-1,1))
Y_M09 = Y_M09.reshape((-1,1))
Y_D09 = Y_D09.reshape((-1,1))
Y_M10 = Y_M10.reshape((-1,1))
Y_D10 = Y_D10.reshape((-1,1))
Y_M11 = Y_M11.reshape((-1,1))
Y_D11 = Y_D11.reshape((-1,1))
ShR = ShR.reshape((-1,1))

# %% [markdown]
# # Flow Curves

# %%
import matplotlib.font_manager
from matplotlib import rc
rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
rc('text', usetex=True)

plt.figure(figsize=(10,10),dpi=300)

plt.rc('font', size=20)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=22)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=22)    # legend fontsize
plt.rc('figure', titlesize=22)  # fontsize of the figure title

plt.plot(np.power(10,ShR),np.power(10,Y_A) , 'k-', markerfacecolor='none', linewidth=3, markersize = 11.0)
plt.plot(np.power(10,ShR[0::2]),np.power(10,Y_M02[0::2]) , 'r<:' , markerfacecolor='none', linewidth=1.5, markersize = 11.0)
plt.plot(np.power(10,ShR[1::3]),np.power(10,Y_M05[1::3]) , 'yo:', markerfacecolor='none', linewidth=1.5, markersize = 11.0)
plt.plot(np.power(10,ShR[0::3]),np.power(10,Y_M08[0::3]) , 'bd:', markerfacecolor='none', linewidth=1.5, markersize = 11.0)
plt.plot(np.power(10,ShR[2::3]),np.power(10,Y_M11[2::3]) , 'gP:', markerfacecolor='none', linewidth=1.5, markersize = 11.0)

plt.xlabel('Shear Rate [1/s]', fontname = 'Times New Roman', fontsize=40)
plt.ylabel('Viscosity [Pa.s]', fontname = 'Times New Roman', fontsize=40)
plt.legend(['Experiment','Up to 2 Months','Up to 5 Months','Up to 8 Months','Up to 11 Months'],loc='upper right')
#plt.title('Actual and Predicted Flow Curve for a Random Batch')

plt.xticks(np.arange(0,10, 1.0),fontname = "Times New Roman", fontsize=30)
plt.yticks(fontname = "Times New Roman", fontsize=30)
#plt.ylim(0.6,13)
plt.xscale("log")
plt.yscale("log")

#plt.savefig('AginWithinBatch13MFNN.png',bbox_inches = 'tight')

plt.show()

# %%
import matplotlib.font_manager
from matplotlib import rc
rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
rc('text', usetex=True)

plt.figure(figsize=(10,10),dpi=300)

plt.rc('font', size=20)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=22)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=22)    # legend fontsize
plt.rc('figure', titlesize=22)  # fontsize of the figure title

plt.plot(np.power(10,ShR),np.power(10,Y_A) , 'k-', markerfacecolor='none', linewidth=3, markersize = 11.0)
plt.plot(np.power(10,ShR[0::2]),np.power(10,Y_D02[0::2]) , 'r<:' , markerfacecolor='none', linewidth=1.5, markersize = 11.0)
plt.plot(np.power(10,ShR[1::3]),np.power(10,Y_D05[1::3]) , 'yo:', markerfacecolor='none', linewidth=1.5, markersize = 11.0)
plt.plot(np.power(10,ShR[0::3]),np.power(10,Y_D08[0::3]) , 'bd:', markerfacecolor='none', linewidth=1.5, markersize = 11.0)
plt.plot(np.power(10,ShR[2::3]),np.power(10,Y_D11[2::3]) , 'gP:', markerfacecolor='none', linewidth=1.5, markersize = 11.0)

plt.xlabel('Shear Rate [1/s]', fontname = 'Times New Roman', fontsize=40)
plt.ylabel('Viscosity [Pa.s]', fontname = 'Times New Roman', fontsize=40)
plt.legend(['Experiment','Up to 2 Months','Up to 5 Months','Up to 8 Months','Up to 11 Months'])#,loc='upper right')
#plt.title('Actual and Predicted Flow Curve for a Random Batch')

plt.xticks(np.arange(0,10, 1.0),fontname = "Times New Roman", fontsize=30)
plt.yticks(fontname = "Times New Roman", fontsize=30)
#plt.ylim(0.6,13)
plt.xscale("log")
plt.yscale("log")

plt.savefig('AginWithinBatch13DNN.png',bbox_inches = 'tight')

plt.show()

# %%
color="0.x"

import matplotlib.font_manager
from matplotlib import rc
rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
rc('text', usetex=True)

plt.figure(figsize=(10,10),dpi=300)

plt.rc('font', size=20)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=22)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=22)    # legend fontsize
plt.rc('figure', titlesize=22)  # fontsize of the figure title

line1, = plt.plot(np.power(10,ShR),np.power(10,Y_M02) , label="2" , color="0.25" , markerfacecolor='none', linewidth=2, markersize = 11.0)
line2, = plt.plot(np.power(10,ShR),np.power(10,Y_M03) , label="3" , color="0.35" , markerfacecolor='none', linewidth=2, markersize = 11.0)
line3, = plt.plot(np.power(10,ShR),np.power(10,Y_M04) , label="4" , color="0.40" , markerfacecolor='none', linewidth=2, markersize = 11.0)
line4, = plt.plot(np.power(10,ShR),np.power(10,Y_M05) , label="5" , color="0.45" , markerfacecolor='none', linewidth=2, markersize = 11.0)
line5, = plt.plot(np.power(10,ShR),np.power(10,Y_M06) , label="6" , color="0.50" , markerfacecolor='none', linewidth=2, markersize = 11.0)
line6, = plt.plot(np.power(10,ShR),np.power(10,Y_M07) , label="7" , color="0.55" , markerfacecolor='none', linewidth=2, markersize = 11.0)
line7, = plt.plot(np.power(10,ShR),np.power(10,Y_M08) , label="8" , color="0.65" , markerfacecolor='none', linewidth=2, markersize = 11.0)
line8, = plt.plot(np.power(10,ShR),np.power(10,Y_M09) , label="9" , color="0.75" , markerfacecolor='none', linewidth=2, markersize = 11.0)
line9, = plt.plot(np.power(10,ShR),np.power(10,Y_M10) , label="10" , color="0.85" , markerfacecolor='none', linewidth=2, markersize = 11.0)
line10, = plt.plot(np.power(10,ShR),np.power(10,Y_M11) , label="11" , color="0.95" , markerfacecolor='none', linewidth=2, markersize = 11.0)
line11, = plt.plot(np.power(10,ShR[::2]),np.power(10,Y_A[::2]), 'b:P' , label="Experiment - 12 months aged" , markerfacecolor='none', linewidth=1.5, markersize = 11.0)

plt.xlabel('Shear Rate [1/s]', fontname = 'Times New Roman', fontsize=40)
plt.ylabel('Viscosity [Pa.s]', fontname = 'Times New Roman', fontsize=40)


first_legend = plt.legend(handles=[line11], bbox_to_anchor=(0.36,0.99))

# Add the legend manually to the current Axes.
plt.gca().add_artist(first_legend)

# Create another legend for the second line.
plt.legend(handles=[line1,line2,line3,line4,line5,line6,line7,line8,line9,line10] ,title='MFNN - trained up to: [months]', bbox_to_anchor=(0.47,0.5),ncol=2)

plt.xticks(np.arange(0,10, 1.0),fontname = "Times New Roman", fontsize=30)
plt.yticks(fontname = "Times New Roman", fontsize=30)
#plt.ylim(0.6,13)
plt.xscale("log")
plt.yscale("log")

plt.savefig('AginWithinBatch13MFNNGray.png',bbox_inches = 'tight')

plt.show()

# %%
color="0.x"

import matplotlib.font_manager
from matplotlib import rc
rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
rc('text', usetex=True)

plt.figure(figsize=(10,10),dpi=300)

plt.rc('font', size=20)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=22)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=22)    # legend fontsize
plt.rc('figure', titlesize=22)  # fontsize of the figure title

line1, = plt.plot(np.power(10,ShR),np.power(10,Y_D02) , label="2" , color="0.25" , markerfacecolor='none', linewidth=2, markersize = 11.0)
line2, = plt.plot(np.power(10,ShR),np.power(10,Y_D03) , label="3" , color="0.35" , markerfacecolor='none', linewidth=2, markersize = 11.0)
line3, = plt.plot(np.power(10,ShR),np.power(10,Y_D04) , label="4" , color="0.40" , markerfacecolor='none', linewidth=2, markersize = 11.0)
line4, = plt.plot(np.power(10,ShR),np.power(10,Y_D05) , label="5" , color="0.45" , markerfacecolor='none', linewidth=2, markersize = 11.0)
line5, = plt.plot(np.power(10,ShR),np.power(10,Y_D06) , label="6" , color="0.50" , markerfacecolor='none', linewidth=2, markersize = 11.0)
line6, = plt.plot(np.power(10,ShR),np.power(10,Y_D07) , label="7" , color="0.55" , markerfacecolor='none', linewidth=2, markersize = 11.0)
line7, = plt.plot(np.power(10,ShR),np.power(10,Y_D08) , label="8" , color="0.65" , markerfacecolor='none', linewidth=2, markersize = 11.0)
line8, = plt.plot(np.power(10,ShR),np.power(10,Y_D09) , label="9" , color="0.75" , markerfacecolor='none', linewidth=2, markersize = 11.0)
line9, = plt.plot(np.power(10,ShR),np.power(10,Y_D10) , label="10" , color="0.85" , markerfacecolor='none', linewidth=2, markersize = 11.0)
line10, = plt.plot(np.power(10,ShR),np.power(10,Y_D11) , label="11" , color="0.95" , markerfacecolor='none', linewidth=2, markersize = 11.0)
line11, = plt.plot(np.power(10,ShR[::2]),np.power(10,Y_A[::2]), 'b:P' , label="Experiment - 12 months aged" , markerfacecolor='none', linewidth=1.5, markersize = 11.0)

plt.xlabel('Shear Rate [1/s]', fontname = 'Times New Roman', fontsize=40)
plt.ylabel('Viscosity [Pa.s]', fontname = 'Times New Roman', fontsize=40)


first_legend = plt.legend(handles=[line11], bbox_to_anchor=(0.365,0.87))

# Add the legend manually to the current Axes.
plt.gca().add_artist(first_legend)

# Create another legend for the second line.
plt.legend(handles=[line1,line2,line3,line4,line5,line6,line7,line8,line9,line10] ,title='DNN - trained up to: [months]', bbox_to_anchor=(0.5,0.69),ncol=2)

#plt.title('Actual and Predicted Flow Curve for a Random Batch')

plt.xticks(np.arange(0,10, 1.0),fontname = "Times New Roman", fontsize=30)
plt.yticks(fontname = "Times New Roman", fontsize=30)
#plt.ylim(0.6,13)
plt.xscale("log")
plt.yscale("log")

plt.savefig('AginWithinBatch13DNNGray.png',bbox_inches = 'tight')

plt.show()

# %%
color="0.x"

import matplotlib.font_manager
from matplotlib import rc
rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
rc('text', usetex=True)

plt.figure(figsize=(10,10),dpi=300)

plt.rc('font', size=20)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=22)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=22)    # legend fontsize
plt.rc('figure', titlesize=22)  # fontsize of the figure title

plt.plot(np.power(10,ShR),np.power(10,Y_A) , 'b:P', markerfacecolor='none', linewidth=1.5, markersize = 11.0)
plt.plot(np.power(10,ShR[0::2]),np.power(10,Y_M02[0::2]) , color = (0,0.40,0,1) , markerfacecolor='none', linewidth=2, markersize = 11.0)
plt.plot(np.power(10,ShR[0::2]),np.power(10,Y_M03[0::2]) , color = (0,0.45,0,1) , markerfacecolor='none', linewidth=2, markersize = 11.0)
plt.plot(np.power(10,ShR[0::2]),np.power(10,Y_M04[0::2]) , color = (0,0.50,0,1) , markerfacecolor='none', linewidth=2, markersize = 11.0)
plt.plot(np.power(10,ShR[0::2]),np.power(10,Y_M05[0::2]) , color = (0,0.55,0,1) , markerfacecolor='none', linewidth=2, markersize = 11.0)
plt.plot(np.power(10,ShR[0::2]),np.power(10,Y_M06[0::2]) , color = (0,0.60,0,1) , markerfacecolor='none', linewidth=2, markersize = 11.0)
plt.plot(np.power(10,ShR[0::2]),np.power(10,Y_M07[0::2]) , color = (0,0.65,0,1) , markerfacecolor='none', linewidth=2, markersize = 11.0)
plt.plot(np.power(10,ShR[0::2]),np.power(10,Y_M08[0::2]) , color = (0,0.70,0,1) , markerfacecolor='none', linewidth=2, markersize = 11.0)
plt.plot(np.power(10,ShR[0::2]),np.power(10,Y_M09[0::2]) , color = (0,0.75,0,1) , markerfacecolor='none', linewidth=2, markersize = 11.0)
plt.plot(np.power(10,ShR[1::3]),np.power(10,Y_M10[1::3]) , color = (0,0.80,0,1) , markerfacecolor='none', linewidth=2, markersize = 11.0)
plt.plot(np.power(10,ShR[2::3]),np.power(10,Y_M11[2::3]) , color = (0,0.85,0,1) , markerfacecolor='none', linewidth=2, markersize = 11.0)

plt.xlabel('Shear Rate [1/s]', fontname = 'Times New Roman', fontsize=40)
plt.ylabel('Viscosity [Pa.s]', fontname = 'Times New Roman', fontsize=40)
plt.legend(['Experiment','Up to 2 Months','Up to 3 Months','Up to 4 Months','Up to 5 Months'
           ,'Up to 6 Months','Up to 7 Months','Up to 8 Months','Up to 9 Months'
           ,'Up to 10 Months','Up to 11 Months'],loc='upper right')
#plt.title('Actual and Predicted Flow Curve for a Random Batch')

plt.xticks(np.arange(0,10, 1.0),fontname = "Times New Roman", fontsize=30)
plt.yticks(fontname = "Times New Roman", fontsize=30)
#plt.ylim(0.6,13)
plt.xscale("log")
plt.yscale("log")

plt.savefig('AginWithinBatch13MFNNGreen.png',bbox_inches = 'tight')

plt.show()

# %%
color="0.x"

import matplotlib.font_manager
from matplotlib import rc
rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
rc('text', usetex=True)

plt.figure(figsize=(10,10),dpi=300)

plt.rc('font', size=20)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=22)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=22)    # legend fontsize
plt.rc('figure', titlesize=22)  # fontsize of the figure title

plt.plot(np.power(10,ShR[::2]),np.power(10,Y_A[::2]) , 'b:P', markerfacecolor='none', linewidth=1.5, markersize = 11.0)
plt.plot(np.power(10,ShR),np.power(10,Y_M02) , color = (0.5,0.5,0,1) , markerfacecolor='none', linewidth=2, markersize = 11.0)
plt.plot(np.power(10,ShR),np.power(10,Y_M03) , color = (0,0.4,0,1) , markerfacecolor='none', linewidth=2, markersize = 11.0)
plt.plot(np.power(10,ShR),np.power(10,Y_M04) , color = (0.4,0,0,1) , markerfacecolor='none', linewidth=2, markersize = 11.0)
plt.plot(np.power(10,ShR),np.power(10,Y_M05) , color = (0,0.6,0,1) , markerfacecolor='none', linewidth=2, markersize = 11.0)
plt.plot(np.power(10,ShR),np.power(10,Y_M06) , color = (0.6,0,0,1) , markerfacecolor='none', linewidth=2, markersize = 11.0)
plt.plot(np.power(10,ShR),np.power(10,Y_M07) , color = (0,0.8,0,1) , markerfacecolor='none', linewidth=2, markersize = 11.0)
plt.plot(np.power(10,ShR),np.power(10,Y_M08) , color = (0.8,0,0,1) , markerfacecolor='none', linewidth=2, markersize = 11.0)
plt.plot(np.power(10,ShR),np.power(10,Y_M09) , color = (0,1,0,1) , markerfacecolor='none', linewidth=2, markersize = 11.0)
plt.plot(np.power(10,ShR),np.power(10,Y_M10) , color = (1,0,0,1) , markerfacecolor='none', linewidth=2, markersize = 11.0)
plt.plot(np.power(10,ShR),np.power(10,Y_M11) , color = (0,0,0,1) , markerfacecolor='none', linewidth=2, markersize = 11.0)

plt.xlabel('Shear Rate [1/s]', fontname = 'Times New Roman', fontsize=40)
plt.ylabel('Viscosity [Pa.s]', fontname = 'Times New Roman', fontsize=40)
plt.legend(['Experiment','Up to 2 Months','Up to 3 Months','Up to 4 Months','Up to 5 Months'
           ,'Up to 6 Months','Up to 7 Months','Up to 8 Months','Up to 9 Months'
           ,'Up to 10 Months','Up to 11 Months'],loc='upper right')
#plt.title('Actual and Predicted Flow Curve for a Random Batch')

plt.xticks(np.arange(0,10, 1.0),fontname = "Times New Roman", fontsize=30)
plt.yticks(fontname = "Times New Roman", fontsize=30)
#plt.ylim(0.6,13)
plt.xscale("log")
plt.yscale("log")

plt.savefig('AginWithinBatch13MFNNMixed.png',bbox_inches = 'tight')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}
</style>
""")
# Out:
# <style>.container { width:80% !important; }</style>
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>

# %%
cd
# Out:
# /Users/mohammadaminmahmoudabadbozchelou

# %%
Y_A = np.genfromtxt('4PG/4th/4R/Y_A.txt')
Y_M = np.genfromtxt('4PG/4th/4R/Y_M.txt')
Y_D = np.genfromtxt('4PG/4th/4R/Y_D.txt')
ShR = np.genfromtxt('4PG/4th/4R/ShR.txt')

Y_A = Y_A.reshape((-1,1))
Y_M = Y_M.reshape((-1,1))
Y_D = Y_D.reshape((-1,1))
ShR = ShR.reshape((-1,1))

# %% [markdown]
# # Flow Curves for NNs without last 4 Month

# %% [markdown]
# ## 3 to last Month

# %%
a=0*42
b=1*42

plt.figure(figsize=(10,10))

plt.rc('font', size=20)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=22)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=22)  # fontsize of the figure title

plt.plot(np.power(10,ShR[a:b]),np.power(10,Y_A[a:b]) , 'b*-.', linewidth=2.0, markersize = 6.0)
plt.plot(np.power(10,ShR[a:b]),np.power(10,Y_M[a:b]) , 'gd:' , linewidth=2.0, markersize = 6.0)
plt.plot(np.power(10,ShR[a:b]),np.power(10,Y_D[a:b]) , 'ro--', linewidth=2.0, markersize = 6.0)

plt.xlabel('Shear Rate [1/s]')
plt.ylabel('Viscosity [Pa.s]')
plt.legend(['Actual Data from Experiment','Predicted Data using MPINN','Predicted Data using DNN','Predicted Data using Model'])
plt.title('Actual and Predicted Flow Curve for a Random Batch')

plt.xscale("log")

plt.savefig('4PG/4th/4R/4R_1.png')

plt.show()

# %% [markdown]
# ## 2 to last Month

# %%
a=1*42
b=2*42

plt.figure(figsize=(10,10))

plt.rc('font', size=20)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=22)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=22)  # fontsize of the figure title

plt.plot(np.power(10,ShR[a:b]),np.power(10,Y_A[a:b]) , 'b*-.', linewidth=2.0, markersize = 6.0)
plt.plot(np.power(10,ShR[a:b]),np.power(10,Y_M[a:b]) , 'gd:' , linewidth=2.0, markersize = 6.0)
plt.plot(np.power(10,ShR[a:b]),np.power(10,Y_D[a:b]) , 'ro--', linewidth=2.0, markersize = 6.0)

plt.xlabel('Shear Rate [1/s]')
plt.ylabel('Viscosity [Pa.s]')
plt.legend(['Actual Data from Experiment','Predicted Data using MPINN','Predicted Data using DNN','Predicted Data using Model'])
plt.title('Actual and Predicted Flow Curve for a Random Batch')

plt.xscale("log")

plt.savefig('4PG/4th/4R/4R_2.png')

plt.show()

# %% [markdown]
# ## 1 to last Month

# %%
a=2*42
b=3*42

plt.figure(figsize=(10,10))

plt.rc('font', size=20)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=22)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=22)  # fontsize of the figure title

plt.plot(np.power(10,ShR[a:b]),np.power(10,Y_A[a:b]) , 'b*-.', linewidth=2.0, markersize = 6.0)
plt.plot(np.power(10,ShR[a:b]),np.power(10,Y_M[a:b]) , 'gd:' , linewidth=2.0, markersize = 6.0)
plt.plot(np.power(10,ShR[a:b]),np.power(10,Y_D[a:b]) , 'ro--', linewidth=2.0, markersize = 6.0)

plt.xlabel('Shear Rate [1/s]')
plt.ylabel('Viscosity [Pa.s]')
plt.legend(['Actual Data from Experiment','Predicted Data using MPINN','Predicted Data using DNN','Predicted Data using Model'])
plt.title('Actual and Predicted Flow Curve for a Random Batch')

plt.xscale("log")

plt.savefig('4PG/4th/4R/4R_3.png')

plt.show()

# %% [markdown]
# ## Last Month

# %%
a=3*42
b=4*42

plt.figure(figsize=(10,10))

plt.rc('font', size=20)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=22)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=22)  # fontsize of the figure title

plt.plot(np.power(10,ShR[a:b]),np.power(10,Y_A[a:b]) , 'b*-.', linewidth=2.0, markersize = 6.0)
plt.plot(np.power(10,ShR[a:b]),np.power(10,Y_M[a:b]) , 'gd:' , linewidth=2.0, markersize = 6.0)
plt.plot(np.power(10,ShR[a:b]),np.power(10,Y_D[a:b]) , 'ro--', linewidth=2.0, markersize = 6.0)

plt.xlabel('Shear Rate [1/s]')
plt.ylabel('Viscosity [Pa.s]')
plt.legend(['Actual Data from Experiment','Predicted Data using MPINN','Predicted Data using DNN','Predicted Data using Model'])
plt.title('Actual and Predicted Flow Curve for a Random Batch')

plt.xscale("log")

plt.savefig('4PG/4th/4R/4R_4.png')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}
</style>
""")
# Out:
# <style>.container { width:80% !important; }</style>
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>

# %%
Y_A_06M = np.genfromtxt('Y_A_06M.txt')
Y_M_06M = np.genfromtxt('Y_M_06M.txt')
Y_D_06M = np.genfromtxt('Y_D_06M.txt')
ShR_06M = np.genfromtxt('ShR_06M.txt')
Y_A_12M = np.genfromtxt('Y_A_12M.txt')
Y_M_12M = np.genfromtxt('Y_M_12M.txt')
Y_D_12M = np.genfromtxt('Y_D_12M.txt')
ShR_12M = np.genfromtxt('ShR_12M.txt')

Y_A_06M = Y_A_06M.reshape((-1,1))
Y_M_06M = Y_M_06M.reshape((-1,1))
Y_D_06M = Y_D_06M.reshape((-1,1))
ShR_06M = ShR_06M.reshape((-1,1))
Y_A_12M = Y_A_12M.reshape((-1,1))
Y_M_12M = Y_M_12M.reshape((-1,1))
Y_D_12M = Y_D_12M.reshape((-1,1))
ShR_12M = ShR_12M.reshape((-1,1))

# %% [markdown]
# # Flow Curves

# %% [markdown]
# ## 6 & 12 Month together

# %%
import matplotlib.font_manager
from matplotlib import rc
rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
rc('text', usetex=True)

plt.figure(figsize=(10,10),dpi=300)

plt.rc('font', size=20)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=22)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=22)    # legend fontsize
plt.rc('figure', titlesize=22)  # fontsize of the figure title

plt.plot(np.power(10,ShR_06M[0::2]),np.power(10,Y_A_06M[0::2]) , 'b-*', markerfacecolor='none', linewidth=3, markersize = 11.0)
plt.plot(np.power(10,ShR_06M[0::2]),np.power(10,Y_M_06M[0::2]) , 'go:' , markerfacecolor='none', linewidth=1.5, markersize = 11.0)
plt.plot(np.power(10,ShR_06M[1::2]),np.power(10,Y_D_06M[1::2]) , 'rs:', markerfacecolor='none', linewidth=1.5, markersize = 11.0)

plt.plot(np.power(10,ShR_12M[0::2]),np.power(10,Y_A_12M[0::2]) , 'b-P', markerfacecolor='none', linewidth=3, markersize = 11.0)
plt.plot(np.power(10,ShR_12M[0::2]),np.power(10,Y_M_12M[0::2]) , 'gp:', markerfacecolor='none', linewidth=1.5, markersize = 11.0)
plt.plot(np.power(10,ShR_12M[1::2]),np.power(10,Y_D_12M[1::2]) , 'rd:', markerfacecolor='none', linewidth=1.5, markersize = 11.0)

plt.xlabel('Shear Rate [1/s]', fontname = 'Times New Roman', fontsize=40)
plt.ylabel('Viscosity [Pa.s]', fontname = 'Times New Roman', fontsize=40)
plt.legend(['Experiment - Month 6','MFNN - Month 6','DNN - Month 6','Experiment - Month 12','MFNN - Month 12','DNN - Month 12'],loc='upper right')
#plt.title('Actual and Predicted Flow Curve for a Random Batch')

plt.xticks(np.arange(0,10, 1.0),fontname = "Times New Roman", fontsize=30)
plt.yticks(fontname = "Times New Roman", fontsize=30)
plt.ylim(0.11,40)
plt.xscale("log")
plt.yscale("log")

#plt.savefig('AginWithinBatch13MFNN.png',bbox_inches = 'tight')

plt.show()

# %% [markdown]
# ## 6th Month

# %%
a=0*42
b=1*42

plt.figure(figsize=(10,10))

plt.rc('font', size=20)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=22)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=22)  # fontsize of the figure title

plt.plot(np.power(10,ShR[a:b]),np.power(10,Y_A[a:b]) , 'b*-.', linewidth=2.0, markersize = 6.0)
plt.plot(np.power(10,ShR[a:b]),np.power(10,Y_M[a:b]) , 'gd:' , linewidth=2.0, markersize = 6.0)
plt.plot(np.power(10,ShR[a:b]),np.power(10,Y_D[a:b]) , 'ro--', linewidth=2.0, markersize = 6.0)
plt.plot(Model_Shr[401*1:401*2] , Model_Vis[401*1:401*2]  , 'k<--', linewidth=2.0, markersize = 6.0)

plt.xlabel('Shear Rate [1/s]')
plt.ylabel('Viscosity [Pa.s]')
plt.legend(['Actual Data from Experiment','Predicted Data using MPINN','Predicted Data using DNN','Predicted Data using Model'])
plt.title('Actual and Predicted Flow Curve for a Random Batch')

plt.xscale("log")

plt.show()

# %% [markdown]
# ## 12th Month

# %%
a=1*42
b=2*42

plt.figure(figsize=(10,10))

plt.rc('font', size=20)          # controls default text sizes
plt.rc('axes', titlesize=20)     # fontsize of the axes title
plt.rc('axes', labelsize=22)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels
plt.rc('legend', fontsize=20)    # legend fontsize
plt.rc('figure', titlesize=22)  # fontsize of the figure title

plt.plot(np.power(10,ShR[a:b]),np.power(10,Y_A[a:b]) , 'b*-.', linewidth=2.0, markersize = 6.0)
plt.plot(np.power(10,ShR[a:b]),np.power(10,Y_M[a:b]) , 'gd:' , linewidth=2.0, markersize = 6.0)
plt.plot(np.power(10,ShR[a:b]),np.power(10,Y_D[a:b]) , 'ro--', linewidth=2.0, markersize = 6.0)
plt.plot(Model_Shr[401*2:401*3] , Model_Vis[401*2:401*3]  , 'k<--', linewidth=2.0, markersize = 6.0)

plt.xlabel('Shear Rate [1/s]')
plt.ylabel('Viscosity [Pa.s]')
plt.legend(['Actual Data from Experiment','Predicted Data using MPINN','Predicted Data using DNN','Predicted Data using Model'])
plt.title('Actual and Predicted Flow Curve for a Random Batch')

plt.xscale("log")

plt.show()
